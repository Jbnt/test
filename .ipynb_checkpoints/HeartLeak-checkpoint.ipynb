# %% [markdown]
# # Heart Disease

# %% [markdown]
# ## 1. Data Preparation

# %% [markdown]
# ### 1.1 Get Data

# %%
#Get data
import pandas as pd
train_values = pd.read_csv('https://s3.amazonaws.com/drivendata/data/54/public/train_values.csv')
train_labels = pd.read_csv('https://s3.amazonaws.com/drivendata/data/54/public/train_labels.csv')

# %%
#Join data together
#heartdata = pd.merge(train_values, train_labels, how = 'inner', on = 'patient_id')

heartdata = train_values

# %%
train_values.head(5)
# Out:
#   patient_id  slope_of_peak_exercise_st_segment               thal  \
# 0     0z64un                                  1             normal
# 1     ryoo3j                                  2             normal
# 2     yt1s1x                                  1             normal
# 3     l2xjde                                  1  reversible_defect
# 4     oyt4ek                                  3  reversible_defect
#
#    resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                     128                2                  0
# 1                     110                3                  0
# 2                     125                4                  3
# 3                     152                4                  0
# 4                     178                1                  0
#
#    fasting_blood_sugar_gt_120_mg_per_dl  resting_ekg_results  \
# 0                                     0                    2
# 1                                     0                    0
# 2                                     0                    2
# 3                                     0                    0
# 4                                     0                    2
#
#    serum_cholesterol_mg_per_dl  oldpeak_eq_st_depression  sex  age  \
# 0                          308                       0.0    1   45
# 1                          214                       1.6    0   54
# 2                          304                       0.0    1   77
# 3                          223                       0.0    1   40
# 4                          270                       4.2    1   59
#
#    max_heart_rate_achieved  exercise_induced_angina
# 0                      170                        0
# 1                      158                        0
# 2                      162                        1
# 3                      181                        0
# 4                      145                        0

# %%
train_labels.head()
# Out:
#   patient_id  heart_disease_present
# 0     0z64un                      0
# 1     ryoo3j                      0
# 2     yt1s1x                      1
# 3     l2xjde                      1
# 4     oyt4ek                      0

# %%
heartdata.head()
# Out:
#   patient_id  slope_of_peak_exercise_st_segment               thal  \
# 0     0z64un                                  1             normal
# 1     ryoo3j                                  2             normal
# 2     yt1s1x                                  1             normal
# 3     l2xjde                                  1  reversible_defect
# 4     oyt4ek                                  3  reversible_defect
#
#    resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                     128                2                  0
# 1                     110                3                  0
# 2                     125                4                  3
# 3                     152                4                  0
# 4                     178                1                  0
#
#    fasting_blood_sugar_gt_120_mg_per_dl  resting_ekg_results  \
# 0                                     0                    2
# 1                                     0                    0
# 2                                     0                    2
# 3                                     0                    0
# 4                                     0                    2
#
#    serum_cholesterol_mg_per_dl  oldpeak_eq_st_depression  sex  age  \
# 0                          308                       0.0    1   45
# 1                          214                       1.6    0   54
# 2                          304                       0.0    1   77
# 3                          223                       0.0    1   40
# 4                          270                       4.2    1   59
#
#    max_heart_rate_achieved  exercise_induced_angina
# 0                      170                        0
# 1                      158                        0
# 2                      162                        1
# 3                      181                        0
# 4                      145                        0

# %% [markdown]
# ### 1.2 Analyse & Clean data

# %%
heartdata.describe()
# Out:
#        slope_of_peak_exercise_st_segment  resting_blood_pressure  \
# count                         180.000000              180.000000
# mean                            1.550000              131.311111
# std                             0.618838               17.010443
# min                             1.000000               94.000000
# 25%                             1.000000              120.000000
# 50%                             1.000000              130.000000
# 75%                             2.000000              140.000000
# max                             3.000000              180.000000
#
#        chest_pain_type  num_major_vessels  \
# count       180.000000         180.000000
# mean          3.155556           0.694444
# std           0.938454           0.969347
# min           1.000000           0.000000
# 25%           3.000000           0.000000
# 50%           3.000000           0.000000
# 75%           4.000000           1.000000
# max           4.000000           3.000000
#
#        fasting_blood_sugar_gt_120_mg_per_dl  resting_ekg_results  \
# count                            180.000000           180.000000
# mean                               0.161111             1.050000
# std                                0.368659             0.998742
# min                                0.000000             0.000000
# 25%                                0.000000             0.000000
# 50%                                0.000000             2.000000
# 75%                                0.000000             2.000000
# max                                1.000000             2.000000
#
#        serum_cholesterol_mg_per_dl  oldpeak_eq_st_depression         sex  \
# count                   180.000000                180.000000  180.000000
# mean                    249.211111                  1.010000    0.688889
# std                      52.717969                  1.121357    0.464239
# min                     126.000000                  0.000000    0.000000
# 25%                     213.750000                  0.000000    0.000000
# 50%                     245.500000                  0.800000    1.000000
# 75%                     281.250000                  1.600000    1.000000
# max                     564.000000                  6.200000    1.000000
#
#               age  max_heart_rate_achieved  exercise_induced_angina
# count  180.000000               180.000000               180.000000
# mean    54.811111               149.483333                 0.316667
# std      9.334737                22.063513                 0.466474
# min     29.000000                96.000000                 0.000000
# 25%     48.000000               132.000000                 0.000000
# 50%     55.000000               152.000000                 0.000000
# 75%     62.000000               166.250000                 1.000000
# max     77.000000               202.000000                 1.000000

# %%
heartdata.isnull().any().any()
#no missing values
# Out:
# False

# %%
#Determine possible categorical variables (for 1 hot encoding)
heartdata['resting_ekg_results'].value_counts()
# Out:
# 2    94
# 0    85
# 1     1
# Name: resting_ekg_results, dtype: int64

# %%
heartdata['num_major_vessels'].value_counts()
# Out:
# 0    106
# 1     37
# 2     23
# 3     14
# Name: num_major_vessels, dtype: int64

# %%
heartdata['chest_pain_type'].value_counts()
# Out:
# 4    82
# 3    57
# 2    28
# 1    13
# Name: chest_pain_type, dtype: int64

# %%
heartdata['slope_of_peak_exercise_st_segment'].value_counts()
# Out:
# 1    93
# 2    75
# 3    12
# Name: slope_of_peak_exercise_st_segment, dtype: int64

# %%
import matplotlib.pyplot as plt

# Make a line plot: year on the x-axis, pop on the y-axis
plt.scatter(train_values['age'], train_values['max_heart_rate_achieved'])

# Display the plot with plt.show()
plt.show()

# %%
plt.hist(train_values['max_heart_rate_achieved'])
# Out:
# (array([ 7., 12., 15., 17., 27., 33., 36., 24.,  7.,  2.]),
#  array([ 96. , 106.6, 117.2, 127.8, 138.4, 149. , 159.6, 170.2, 180.8,
#         191.4, 202. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### One-hot encoding categorical variables

# %%
#One hot encoding of the thal variable
heartdata['thal'].value_counts()
# Out:
# normal               98
# reversible_defect    74
# fixed_defect          8
# Name: thal, dtype: int64

# %%
heartdata = pd.get_dummies(heartdata, columns = ['thal'])

# %% [markdown]
# # 3.Model Building

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split

# %%
#Join data together
data = pd.merge(heartdata, train_labels, how = 'inner', on = 'patient_id')

# %%
X = data.drop(['heart_disease_present', 'patient_id'], axis = 1)
y = data['heart_disease_present']

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 42) # 70% training and 30% test

# %%
print("Train:", X_train.shape)
print("Test:", X_test.shape)
# Out:
# Train: (126, 15)
# Test: (54, 15)

# %% [markdown]
# ## 3.1 Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=None, max_features='auto', max_leaf_nodes=None,
            min_impurity_decrease=0.0, min_impurity_split=None,
            min_samples_leaf=1, min_samples_split=2,
            min_weight_fraction_leaf=0.0, n_estimators=350, n_jobs=1,
            oob_score=False, random_state=None, verbose=0,
            warm_start=False)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
y_pred_prob=clf.predict_proba(X_test)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
from sklearn.metrics import log_loss


def evaluat_classification_prediction(y_test, y_pred):
    print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
    print("AUC:",metrics.roc_auc_score(y_test, y_pred))
    print("Confusion matrix:", confusion_matrix(y_test, y_pred))
    print("Log Loss:", log_loss(y_test,y_pred_prob))
    
evaluat_classification_prediction(y_test, y_pred)
# Out:
# Accuracy: 0.8333333333333334
# AUC: 0.8448275862068966
# Confusion matrix: [[25  0]
#  [ 9 20]]
# Log Loss: 0.4486320441594104

# %% [markdown]
# ## 3.2 Parameter Sweeping with Random Forest

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.metrics import roc_curve, precision_recall_curve, auc, make_scorer, recall_score, accuracy_score, precision_score, confusion_matrix


from sklearn.tree import DecisionTreeClassifier


#Parameter sweeping
clf = RandomForestClassifier(n_jobs=-1)

param_grid = {
    'min_samples_split': [3, 5, 10], 
    'n_estimators' : [100, 300, 350],
    'max_depth': [3, 5, 15, 25],
    'max_features': [3, 5, 10, 15]
}

scorers = {
    'precision_score': make_scorer(precision_score),
    'recall_score': make_scorer(recall_score),
    'accuracy_score': make_scorer(accuracy_score),
    'AUC': 'roc_auc',
    'Log Loss': 'log_loss'
}

def grid_search_wrapper(refit_score='Log Loss'):
    """
    fits a GridSearchCV classifier using refit_score for optimization
    prints classifier performance metrics
    """
    skf = StratifiedKFold(n_splits=5)
    grid_search = GridSearchCV(clf, param_grid, scoring=scorers, refit=refit_score,
                           cv=skf, return_train_score=True, n_jobs=-1)
    grid_search.fit(X_train.values, y_train.values)

    # make the predictions
    y_pred = grid_search.predict(X_test.values)
    y_pred_prob = grid_search.predict_proba(X_test.values)

    print('Best params for {}'.format(refit_score))
    print(grid_search.best_params_)

    # confusion matrix on the test data.
    print('\nConfusion matrix of Random Forest optimized for {} on the test data:'.format(refit_score))
    print(pd.DataFrame(confusion_matrix(y_test, y_pred),
                 columns=['pred_neg', 'pred_pos'], index=['neg', 'pos']))
    print("Log Loss:", log_loss(y_test,y_pred_prob))
    return grid_search

grid_search_clf = grid_search_wrapper()
# Out:
# Best params for Log Loss
# {'max_depth': 25, 'max_features': 3, 'min_samples_split': 5, 'n_estimators': 300}
#
# Confusion matrix of Random Forest optimized for Log Loss on the test data:
#      pred_neg  pred_pos
# neg        25         0
# pos         9        20
# Log Loss: 0.46083491319053077

# %%
results = pd.DataFrame(grid_search_clf.cv_results_)

results.sort_values(by="mean_test_Log Loss", ascending =False)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 112       0.625731      0.061558         0.540856        0.020633
# 39        0.251464      0.012640         0.529378        0.009218
# 113       0.788376      0.033629         0.532326        0.023444
# 73        0.618473      0.105933         0.560514        0.039773
# 108       0.229173      0.026080         0.521817        0.003102
# 40        0.592387      0.046183         0.539100        0.026317
# 77        0.910663      0.169520         0.581176        0.075553
# 48        0.284903      0.085234         0.535535        0.015285
# 110              25                  3                       3
# 121              25                  5                       5
# 78               15                  3                      10
# 42                5                  3                      10
# 52                5                  5                      10
# 119              25                  5                       3
# 51                5                  5                      10
# 74               15                  3                       3
# 49                5                  5                       5
# 84               15                  5                       5
# 53                5                  5                      10
# 10                3                  5                       3
# 9                 3                  5                       3
# ..              ...                ...                     ...
# 27                3                 15                       3
# 35                3                 15                      10
# 57                5                 10                       5
# 128              25                 10                       3
# 65                5                 15                       3
# 34                3                 15                      10
# 117              25                  5                       3
# 31                3                 15                       5
# 133              25                 10                      10
# 140              25                 15                       5
# 127              25                 10                       3
# 71                5                 15                      10
# 139              25                 15                       5
# 102              15                 15                       5
# 136              25                 15                       3
# 141              25                 15                      10
# 99               15                 15                       3
# 66                5                 15                       5
# 100              15                 15                       3
# 69                5                 15                      10
# 126              25                 10                       3
# 104              15                 15                       5
# 107              15                 15                      10
# 101              15                 15                       3
# 70                5                 15                      10
# 137              25                 15                       3
# 138              25                 15                       5
# 103              15                 15                       5
# 105              15                 15                      10
# 135              25                 15                       3
#
#     param_n_estimators                                             params  \
# 112                300  {'max_depth': 25, 'max_features': 3, 'min_samp...
# 39                 100  {'max_depth': 5, 'max_features': 3, 'min_sampl...
# 113                350  {'max_depth': 25, 'max_features': 3, 'min_samp...
# 73                 300  {'max_depth': 15, 'max_features': 3, 'min_samp...
# 108                100  {'max_depth': 25, 'max_features': 3, 'min_samp...
# 40                 300  {'max_depth': 5, 'max_features': 3, 'min_sampl...
# 77                 350  {'max_depth': 15, 'max_features': 3, 'min_samp...
# 48                 100  {'max_depth': 5, 'max_features': 5, 'min_sampl...
# 76                 300  {'max_depth': 15, 'max_features': 3, 'min_samp...
# 109                300  {'max_depth': 25, 'max_features': 3, 'min_samp...
# 37                 300  {'max_depth': 5, 'max_features': 3, 'min_sampl...
# 38                 350  {'max_depth': 5, 'max_features': 3, 'min_sampl...
# 41                 350  {'max_depth': 5, 'max_features': 3, 'min_sampl...
# 120                100  {'max_depth': 25, 'max_features': 5, 'min_samp...
# 122                350  {'max_depth': 25, 'max_features': 5, 'min_samp...
# 47                 350  {'max_depth': 5, 'max_features': 5, 'min_sampl...
# 72                 100  {'max_depth': 15, 'max_features': 3, 'min_samp...
# 110                350  {'max_depth': 25, 'max_features': 3, 'min_samp...
# 121                300  {'max_depth': 25, 'max_features': 5, 'min_samp...
# 78                 100  {'max_depth': 15, 'max_features': 3, 'min_samp...
# 42                 100  {'max_depth': 5, 'max_features': 3, 'min_sampl...
# 52                 300  {'max_depth': 5, 'max_features': 5, 'min_sampl...
# 119                350  {'max_depth': 25, 'max_features': 5, 'min_samp...
# 51                 100  {'max_depth': 5, 'max_features': 5, 'min_sampl...
# 74                 350  {'max_depth': 15, 'max_features': 3, 'min_samp...
# 49                 300  {'max_depth': 5, 'max_features': 5, 'min_sampl...
# 84                 100  {'max_depth': 15, 'max_features': 5, 'min_samp...
# 53                 350  {'max_depth': 5, 'max_features': 5, 'min_sampl...
# 10                 300  {'max_depth': 3, 'max_features': 5, 'min_sampl...
# 9                  100  {'max_depth': 3, 'max_features': 5, 'min_sampl...
# ..                 ...                                                ...
# 27                 100  {'max_depth': 3, 'max_features': 15, 'min_samp...
# 35                 350  {'max_depth': 3, 'max_features': 15, 'min_samp...
# 57                 100  {'max_depth': 5, 'max_features': 10, 'min_samp...
# 128                350  {'max_depth': 25, 'max_features': 10, 'min_sam...
# 65                 350  {'max_depth': 5, 'max_features': 15, 'min_samp...
# 34                 300  {'max_depth': 3, 'max_features': 15, 'min_samp...
# 117                100  {'max_depth': 25, 'max_features': 5, 'min_samp...
# 31                 300  {'max_depth': 3, 'max_features': 15, 'min_samp...
# 133                300  {'max_depth': 25, 'max_features': 10, 'min_sam...
# 140                350  {'max_depth': 25, 'max_features': 15, 'min_sam...
# 127                300  {'max_depth': 25, 'max_features': 10, 'min_sam...
# 71                 350  {'max_depth': 5, 'max_features': 15, 'min_samp...
# 139                300  {'max_depth': 25, 'max_features': 15, 'min_sam...
# 102                100  {'max_depth': 15, 'max_features': 15, 'min_sam...
# 136                300  {'max_depth': 25, 'max_features': 15, 'min_sam...
# 141                100  {'max_depth': 25, 'max_features': 15, 'min_sam...
# 99                 100  {'max_depth': 15, 'max_features': 15, 'min_sam...
# 66                 100  {'max_depth': 5, 'max_features': 15, 'min_samp...
# 100                300  {'max_depth': 15, 'max_features': 15, 'min_sam...
# 69                 100  {'max_depth': 5, 'max_features': 15, 'min_samp...
# 126                100  {'max_depth': 25, 'max_features': 10, 'min_sam...
# 104                350  {'max_depth': 15, 'max_features': 15, 'min_sam...
# 107                350  {'max_depth': 15, 'max_features': 15, 'min_sam...
# 101                350  {'max_depth': 15, 'max_features': 15, 'min_sam...
# 70                 300  {'max_depth': 5, 'max_features': 15, 'min_samp...
# 137                350  {'max_depth': 25, 'max_features': 15, 'min_sam...
# 138                100  {'max_depth': 25, 'max_features': 15, 'min_sam...
# 103                300  {'max_depth': 15, 'max_features': 15, 'min_sam...
# 105                100  {'max_depth': 15, 'max_features': 15, 'min_sam...
# 135                100  {'max_depth': 25, 'max_features': 15, 'min_sam...
#
#      split0_test_precision_score         ...          mean_test_Log Loss  \
# 112                     0.727273         ...                   -0.425615
# 39                      0.727273         ...                   -0.426130
# 113                     0.700000         ...                   -0.427030
# 73                      0.727273         ...                   -0.427203
# 108                     0.727273         ...                   -0.427921
# 40                      0.727273         ...                   -0.428146
# 77                      0.700000         ...                   -0.428626
# 48                      0.700000         ...                   -0.429569
# 76                      0.700000         ...                   -0.429755
# 109                     0.700000         ...                   -0.430451
# 37                      0.700000         ...                   -0.430662
# 38                      0.700000         ...                   -0.431500
# 41                      0.727273         ...                   -0.431538
# 120                     0.666667         ...                   -0.431634
# 122                     0.700000         ...                   -0.431742
# 47                      0.636364         ...                   -0.431924
# 72                      0.700000         ...                   -0.432314
# 110                     0.727273         ...                   -0.432411
# 121                     0.700000         ...                   -0.432991
# 107              -0.245720            -0.227674            0.010950
# 101              -0.148717            -0.135034            0.009768
# 70               -0.246281            -0.229454            0.012026
# 137              -0.148441            -0.135027            0.008796
# 138              -0.180221            -0.168115            0.009643
# 103              -0.180440            -0.166693            0.009251
# 105              -0.248558            -0.226505            0.012384
# 135              -0.148748            -0.136265            0.009203
#
# [144 rows x 84 columns]

# %%
grid_search_clf.best_params_

# %% [markdown]
# ## 3.3 Feature Importance

# %%
feature_imp = pd.Series(clf.feature_importances_, index=list(X)).sort_values(ascending=False)
feature_imp
# Out:
# oldpeak_eq_st_depression                0.120396
# thal_normal                             0.104712
# age                                     0.097274
# max_heart_rate_achieved                 0.096707
# num_major_vessels                       0.091508
# thal_reversible_defect                  0.079679
# chest_pain_type                         0.077263
# serum_cholesterol_mg_per_dl             0.076796
# resting_blood_pressure                  0.070351
# exercise_induced_angina                 0.067047
# slope_of_peak_exercise_st_segment       0.060814
# sex                                     0.024010
# resting_ekg_results                     0.019270
# fasting_blood_sugar_gt_120_mg_per_dl    0.009896
# thal_fixed_defect                       0.004278
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Creating a bar plot
sns.barplot(x=feature_imp, y=feature_imp.index)
# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
important_test_features = X_test.drop(['thal_fixed_defect','fasting_blood_sugar_gt_120_mg_per_dl','resting_ekg_results'], axis = 1)
important_train_features = X_train.drop(['thal_fixed_defect','fasting_blood_sugar_gt_120_mg_per_dl','resting_ekg_results'], axis = 1)

# %%
clf.fit(important_train_features,y_train)
y_pred=clf.predict(important_test_features)

evaluat_classification_prediction(y_test, y_pred)
# Out:
# Accuracy: 0.8148148148148148
# AUC: 0.8248275862068966
# Accuracy: 0.8148148148148148
# AUC: 0.8248275862068966

# %% [markdown]
# # 4. Deployment

# %% [markdown]
# Best parameters determined by our sweep:
#  'max_depth': 5,
#  'max_features': 3,
#  'min_samples_split': 10,
#  'n_estimators': 100}
#
#
#  'max_depth': 25, 'max_features': 3, 'min_samples_split': 5, 'n_estimators': 300}
#
# Train on all data we have, with these optimal parameters

# %% [markdown]
# ## 4.1 Create large training set

# %%
#Download test data
test_values = pd.read_csv('https://s3.amazonaws.com/drivendata/data/54/public/test_values.csv')
#Apply cleaning
test = pd.get_dummies(test_values, columns = ['thal'])

# %%
X_train = data.drop(['heart_disease_present', 'patient_id'], axis = 1)
y_train = data['heart_disease_present']

X_test = test.drop(['patient_id'], axis = 1)

print(X_test.shape)
print(X_train.shape)
# Out:
# (90, 15)
# (180, 15)

# %% [markdown]
# ## 4.2 Create model with optimal parameters

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=25, max_features=3, max_leaf_nodes=None,
            min_impurity_decrease=0.0, min_impurity_split=None,
            min_samples_leaf=1, min_samples_split=5,
            min_weight_fraction_leaf=0.0, n_estimators=300, n_jobs=1,
            oob_score=False, random_state=None, verbose=0,
            warm_start=False)
clf.fit(X_train,y_train)
y_pred=clf.predict_proba(X_test)

# %%
submission = pd.DataFrame({'patient_id':test['patient_id'],'heart_disease_present':pd.DataFrame(y_pred)[1]})
submission.to_csv("submission.csv", index = False)
